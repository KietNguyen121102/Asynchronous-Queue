# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("greedyComparisonCost0.9.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "numCustomer", "allQueue", "greedy", "pessGreedy", "allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(0,6):
        df_plot = df[df['onlineBarista'] == i]
        df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
        print("df_plot dataframe is below")
        print(df_plot)
       
        plt.plot(df_plot['numCustomer'], df_plot['allQueue'], label = "allQueue")
        plt.plot(df_plot['numCustomer'], df_plot['greedy'], label = "greedy")
        plt.plot(df_plot['numCustomer'], df_plot['pessGreedy'], label = "pessGreedy")
        plt.plot(df_plot['numCustomer'], df_plot['allLine'], label = "allLine")
        plt.legend(loc="upper left", fontsize = "5")

        plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
        plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 5               0.0              5.0             8.0          1.0    0.9
# 11              0.0              5.0             8.0          1.0    0.9
# 17              0.0              5.0             8.0          1.0    0.9
# 23              0.0              5.0             8.0          1.0    0.9
# 29              0.0              5.0             8.0          1.0    0.9
# ...             ...              ...             ...          ...    ...
# 2969            0.0              5.0             8.0          1.0    0.9
# 2975            0.0              5.0             8.0          1.0    0.9
# 2981            0.0              5.0             8.0          1.0    0.9
# 2987            0.0              5.0             8.0          1.0    0.9
# 2993            0.0              5.0             8.0          1.0    0.9
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
# 5             2.0      5.85    7.200000    7.200000      6.5
# 11            3.0      5.85    7.200000    7.200000      6.5
# 17            4.0      5.85    7.200000    7.200000      6.5
# 23            5.0      7.20    7.200000    7.200000      8.0
# 29            6.0      7.20    7.650000    7.650000      8.0
# ...           ...       ...         ...         ...      ...
# 2969        496.0    139.50  152.922984  152.891532    155.0
# 2975        497.0    139.50  153.222535  153.191147    155.0
# 2981        498.0    139.50  153.520884  153.489558    155.0
# 2987        499.0    139.50  153.818036  153.786774    155.0
# 2993        500.0    140.85  154.114000  154.082800    156.5
#
# [499 rows x 10 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 0               1.0              4.0             8.0          1.0    0.9
# 6               1.0              4.0             8.0          1.0    0.9
# 12              1.0              4.0             8.0          1.0    0.9
# 18              1.0              4.0             8.0          1.0    0.9
# 24              1.0              4.0             8.0          1.0    0.9
# ...             ...              ...             ...          ...    ...
# 2970            1.0              4.0             8.0          1.0    0.9
# 2976            1.0              4.0             8.0          1.0    0.9
# 2982            1.0              4.0             8.0          1.0    0.9
# 2988            1.0              4.0             8.0          1.0    0.9
# 2994            1.0              4.0             8.0          1.0    0.9
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
# 0             1.0      5.85    7.200000    7.200000      6.5
# 6             2.0      5.85    7.200000    7.200000      6.5
# 12            3.0      5.85    7.200000    7.200000      6.5
# 18            4.0      5.85    7.200000    7.200000      6.5
# 24            5.0      7.20    7.200000    7.200000      8.0
# ...           ...       ...         ...         ...      ...
# 2970        496.0    139.50  150.352823  150.328024    155.0
# 2976        497.0    139.50  150.657746  150.632998    155.0
# 2982        498.0    139.50  150.906426  150.881727    155.0
# 2988        499.0    139.50  151.208818  151.184168    155.0
# 2994        500.0    140.85  151.510000  151.485400    156.5
#
# [500 rows x 10 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 1               2.0              3.0             8.0          1.0    0.9
# 7               2.0              3.0             8.0          1.0    0.9
# 13              2.0              3.0             8.0          1.0    0.9
# 19              2.0              3.0             8.0          1.0    0.9
# 25              2.0              3.0             8.0          1.0    0.9
# ...             ...              ...             ...          ...    ...
# 2971            2.0              3.0             8.0          1.0    0.9
# 2977            2.0              3.0             8.0          1.0    0.9
# 2983            2.0              3.0             8.0          1.0    0.9
# 2989            2.0              3.0             8.0          1.0    0.9
# 2995            2.0              3.0             8.0          1.0    0.9
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
#
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# allQueue           float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("greedyComparisonCost0.7.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "numCustomer", "allQueue", "greedy", "pessGreedy", "allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(0,6):
        df_plot = df[df['onlineBarista'] == i]
        df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
        print("df_plot dataframe is below")
        print(df_plot)
       
        plt.plot(df_plot['numCustomer'], df_plot['allQueue'], label = "allQueue")
        plt.plot(df_plot['numCustomer'], df_plot['greedy'], label = "greedy")
        plt.plot(df_plot['numCustomer'], df_plot['pessGreedy'], label = "pessGreedy")
        plt.plot(df_plot['numCustomer'], df_plot['allLine'], label = "allLine")
        plt.legend(loc="upper left", fontsize = "5")

        plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
        plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 5               0.0              5.0             8.0          1.0    0.7
# 11              0.0              5.0             8.0          1.0    0.7
# 17              0.0              5.0             8.0          1.0    0.7
# 23              0.0              5.0             8.0          1.0    0.7
# 29              0.0              5.0             8.0          1.0    0.7
# ...             ...              ...             ...          ...    ...
# 2969            0.0              5.0             8.0          1.0    0.7
# 2975            0.0              5.0             8.0          1.0    0.7
# 2981            0.0              5.0             8.0          1.0    0.7
# 2987            0.0              5.0             8.0          1.0    0.7
# 2993            0.0              5.0             8.0          1.0    0.7
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
# 5             2.0      4.55    5.600000    5.600000      6.5
# 11            3.0      4.55    5.600000    5.600000      6.5
# 17            4.0      4.55    5.600000    5.600000      6.5
# 23            5.0      5.60    5.600000    5.600000      8.0
# 29            6.0      5.60    5.950000    5.950000      8.0
# ...           ...       ...         ...         ...      ...
# 2969        496.0    108.50  136.827016  136.412097    155.0
# 2975        497.0    108.50  137.107445  136.693360    155.0
# 2981        498.0    108.50  137.386747  136.973494    155.0
# 2987        499.0    108.50  137.664930  137.252505    155.0
# 2993        500.0    109.55  137.942000  137.530400    156.5
#
# [499 rows x 10 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 0               1.0              4.0             8.0          1.0    0.7
# 6               1.0              4.0             8.0          1.0    0.7
# 12              1.0              4.0             8.0          1.0    0.7
# 18              1.0              4.0             8.0          1.0    0.7
# 24              1.0              4.0             8.0          1.0    0.7
# ...             ...              ...             ...          ...    ...
# 2970            1.0              4.0             8.0          1.0    0.7
# 2976            1.0              4.0             8.0          1.0    0.7
# 2982            1.0              4.0             8.0          1.0    0.7
# 2988            1.0              4.0             8.0          1.0    0.7
# 2994            1.0              4.0             8.0          1.0    0.7
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
# 0             1.0      4.55    5.600000    5.600000      6.5
# 6             2.0      4.55    5.600000    5.600000      6.5
# 12            3.0      4.55    5.600000    5.600000      6.5
# 18            4.0      4.55    5.600000    5.600000      6.5
# 24            5.0      5.60    5.600000    5.600000      8.0
# ...           ...       ...         ...         ...      ...
# 2970        496.0    108.50  131.338710  131.010282    155.0
# 2976        497.0    108.50  131.630785  131.303018    155.0
# 2982        498.0    108.50  131.795181  131.468072    155.0
# 2988        499.0    108.50  132.084569  131.758116    155.0
# 2994        500.0    109.55  132.372800  132.047000    156.5
#
# [500 rows x 10 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 1               2.0              3.0             8.0          1.0    0.7
# 7               2.0              3.0             8.0          1.0    0.7
# 13              2.0              3.0             8.0          1.0    0.7
# 19              2.0              3.0             8.0          1.0    0.7
# 25              2.0              3.0             8.0          1.0    0.7
# ...             ...              ...             ...          ...    ...
# 2971            2.0              3.0             8.0          1.0    0.7
# 2977            2.0              3.0             8.0          1.0    0.7
# 2983            2.0              3.0             8.0          1.0    0.7
# 2989            2.0              3.0             8.0          1.0    0.7
# 2995            2.0              3.0             8.0          1.0    0.7
#
#       numCustomer  allQueue      greedy  pessGreedy  allLine
#
# 22            4.0      4.55    5.600000    5.600000      6.5
# 28            5.0      5.60    5.600000    5.600000      8.0
# ...           ...       ...         ...         ...      ...
# 2974        496.0    108.50  108.711694  108.711694    155.0
# 2980        497.0    108.50  108.922535  108.922535    155.0
# 2986        498.0    108.50  109.132530  109.132530    155.0
# 2992        499.0    108.50  109.341683  109.341683    155.0
# 2998        500.0    109.55  109.550000  109.550000    156.5
#
# [500 rows x 10 columns]
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# allQueue           float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("greedyComparisonCost0.9.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "numCustomer", "allQueue", "greedy", "pessGreedy", "allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])

df['greedy/OPT'] = df['greedy']/df['allQueue']
df['pessGreedy/OPT'] = df['pessGreedy']/df['allQueue']
        
print(df.dtypes)

for i in range(0,6):
        df_plot = df[df['onlineBarista'] == i]
        df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
        df_plot = df_plot[(df_plot['numCustomer'] >= 300) & (df_plot['numCustomer'] <= 400)]

        plt.scatter(df_plot['numCustomer'], df_plot['greedy/OPT'], label = "greedy/OPT")
        # plt.scatter(df_plot['numCustomer'], df_plot['pessGreedy/OPT'], label = "pessGreedy/OPT")
        plt.legend(loc="upper left", fontsize = "5")

        plt.title("Ratio between Greedy and OPT with " + str(i) + " online barista," + str(5-i) + " physical barista: ")
        plt.show()
# Out:
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# allQueue           float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# greedy/OPT         float64
# pessGreedy/OPT     float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("costData0.5.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "numCustomer", "customerNo", "allQueue", "SPNE", "greedy", "pessGreedy", "allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])



df_plot = df[df['onlineBarista'] == 3]
df_plot = df_plot[df_plot['physicalBarista'] == 2]
print("df_plot dataframe is below")
print(df_plot)
       
plt.plot(df_plot['customerNo'], df_plot['allQueue'], label = "allQueue")
plt.plot(df_plot['customerNo'], df_plot['SPNE'], label = "SPNE")
# plt.plot(df_plot['customerNo'], df_plot['greedy'], label = "greedy")
# plt.plot(df_plot['customerNo'], df_plot['pessGreedy'], label = "pessGreedy")
# plt.plot(df_plot['customerNo'], df_plot['allLine'], label = "allLine")
plt.legend(loc="upper left", fontsize = "5")

        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 29            3.0              2.0             8.0          1.0    0.5
# 30            3.0              2.0             8.0          1.0    0.5
# 31            3.0              2.0             8.0          1.0    0.5
# 32            3.0              2.0             8.0          1.0    0.5
# 33            3.0              2.0             8.0          1.0    0.5
# 34            3.0              2.0             8.0          1.0    0.5
# 35            3.0              2.0             8.0          1.0    0.5
# 36            3.0              2.0             8.0          1.0    0.5
# 37            3.0              2.0             8.0          1.0    0.5
# 38            3.0              2.0             8.0          1.0    0.5
# 39            3.0              2.0             8.0          1.0    0.5
# 40            3.0              2.0             8.0          1.0    0.5
# 41            3.0              2.0             8.0          1.0    0.5
# 42            3.0              2.0             8.0          1.0    0.5
# 43            3.0              2.0             8.0          1.0    0.5
#
#     numCustomer  customerNo  allQueue  SPNE  greedy  pessGreedy  allLine
# 29         15.0         1.0       4.0   4.0     4.0         4.0      8.0
# 30         15.0         2.0       4.0   4.0     4.0         4.0      8.0
# 31         15.0         3.0       4.0   4.0     4.0         4.0      8.0
# 32         15.0         4.0       4.0   4.0     4.0         4.0      8.0
# 33         15.0         5.0       4.0   4.0     4.0         4.0      8.0
# 34         15.0         6.0       5.5   5.5     5.5         5.5     11.0
# 35         15.0         7.0       5.5   5.5     5.5         5.5     11.0
# 36         15.0         8.0       5.5   5.5     5.5         5.5     11.0
# 37         15.0         9.0       5.5   5.5     5.5         5.5     11.0
# 38         15.0        10.0       5.5   5.5     5.5         5.5     11.0
# 39         15.0        11.0       7.0   7.0     7.0         7.0     14.0
# 40         15.0        12.0       7.0   7.0     7.0         7.0     14.0
# 41         15.0        13.0       7.0   7.0     7.0         7.0     14.0
# 42         15.0        14.0       7.0   7.0     7.0         7.5     14.0
# 43         15.0        15.0       7.0   7.0     7.0         9.0     14.0
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# customerNo         float64
# allQueue           float64
# SPNE               float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("costData0.9.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "numCustomer", "customerNo", "allQueue", "SPNE", "greedy", "pessGreedy", "allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])



df_plot = df[df['onlineBarista'] == 2]
df_plot = df_plot[df_plot['physicalBarista'] == 3]
print("df_plot dataframe is below")
print(df_plot)
       
plt.plot(df_plot['customerNo'], df_plot['allQueue'], label = "allQueue")
plt.plot(df_plot['customerNo'], df_plot['SPNE'], label = "SPNE")
plt.plot(df_plot['customerNo'], df_plot['greedy'], label = "greedy")
# plt.plot(df_plot['customerNo'], df_plot['pessGreedy'], label = "pessGreedy")
# plt.plot(df_plot['customerNo'], df_plot['allLine'], label = "allLine")
plt.legend(loc="upper left", fontsize = "5")

        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 44            2.0              3.0             8.0          1.0    0.9
# 45            2.0              3.0             8.0          1.0    0.9
# 46            2.0              3.0             8.0          1.0    0.9
# 47            2.0              3.0             8.0          1.0    0.9
# 48            2.0              3.0             8.0          1.0    0.9
# 49            2.0              3.0             8.0          1.0    0.9
# 50            2.0              3.0             8.0          1.0    0.9
# 51            2.0              3.0             8.0          1.0    0.9
# 52            2.0              3.0             8.0          1.0    0.9
# 53            2.0              3.0             8.0          1.0    0.9
# 54            2.0              3.0             8.0          1.0    0.9
# 55            2.0              3.0             8.0          1.0    0.9
# 56            2.0              3.0             8.0          1.0    0.9
# 57            2.0              3.0             8.0          1.0    0.9
# 58            2.0              3.0             8.0          1.0    0.9
#
#     numCustomer  customerNo  allQueue  SPNE  greedy  pessGreedy  allLine
# 44         15.0         1.0       7.2   7.2     7.2         7.2      8.0
# 45         15.0         2.0       7.2   7.2     7.2         7.2      8.0
# 46         15.0         3.0       7.2   7.2     7.2         7.2      8.0
# 47         15.0         4.0       7.2   7.2     7.2         7.2      8.0
# 48         15.0         5.0       7.2   7.2     7.2         7.2      8.0
# 49         15.0         6.0       9.9   9.9     9.9         9.9     11.0
# 50         15.0         7.0       9.9   9.9     9.9        12.0     11.0
# 51         15.0         8.0       9.9  11.0     9.9         9.0     11.0
# 52         15.0         9.0       9.9  11.0     9.9        14.4     11.0
# 53         15.0        10.0       9.9  11.0     9.9        14.4     11.0
# 54         15.0        11.0      12.6  12.6    12.6        15.3     14.0
# 55         15.0        12.0      12.6  12.6    12.6         8.0     14.0
# 56         15.0        13.0      12.6  13.5    13.5         8.0     14.0
# 57         15.0        14.0      12.6  13.0    13.5        13.0     14.0
# 58         15.0        15.0      12.6  12.6    16.2        12.6     14.0
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# customerNo         float64
# allQueue           float64
# SPNE               float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# dtype: object
