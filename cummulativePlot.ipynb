# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("OverTimeCostData0.7.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "processingTime", "arrivalRate", "alpha", "customer", "omniscient", "optimistic", "pessimistic"]


df['pessimistic'] = df['pessimistic'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(0, 6):
    df_plot = df[df['onlineBarista'] == i]
    df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
    print("df_plot dataframe is below")
    print(df_plot)
       
    plt.plot(df_plot['omniscient'], df_plot['customer'], label = "omniscient")
    plt.plot(df_plot['optimistic'], df_plot['customer'], label = "optimistic")
    plt.plot(df_plot['pessimistic'], df_plot['customer'], label = "pessimistic")
   
    plt.title("Num of online baristas: " + str(i) + ", Num of physical baristas:" + str(5-i))
    plt.legend(loc="upper left", fontsize = "5")

        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
    plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 4             0.0              5.0             8.0          1.0    0.7
# 10            0.0              5.0             8.0          1.0    0.7
# 16            0.0              5.0             8.0          1.0    0.7
# 22            0.0              5.0             8.0          1.0    0.7
# 28            0.0              5.0             8.0          1.0    0.7
# 34            0.0              5.0             8.0          1.0    0.7
# 40            0.0              5.0             8.0          1.0    0.7
# 46            0.0              5.0             8.0          1.0    0.7
# 52            0.0              5.0             8.0          1.0    0.7
# 58            0.0              5.0             8.0          1.0    0.7
# 64            0.0              5.0             8.0          1.0    0.7
# 70            0.0              5.0             8.0          1.0    0.7
# 76            0.0              5.0             8.0          1.0    0.7
# 82            0.0              5.0             8.0          1.0    0.7
# 88            0.0              5.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 4           1.0       5.6    5.6     5.6         5.6      8.0
# 10          2.0      11.2   11.2    11.2        11.2     16.0
# 16          3.0      16.8   16.8    16.8        16.8     24.0
# 22          4.0      22.4   22.4    22.4        22.4     32.0
# 28          5.0      28.0   28.0    28.0        28.0     40.0
# 34          6.0      35.7   35.7    35.7        35.7     51.0
# 40          7.0      43.4   43.4    43.4        46.4     62.0
# 46          8.0      51.1   51.1    51.1        54.1     73.0
# 52          9.0      58.8   58.8    58.8        61.8     84.0
# 58         10.0      66.5   66.5    66.5        71.9     95.0
# 64         11.0      76.3   88.3    76.3        84.1    109.0
# 70         12.0      86.1  102.3    86.1        96.3    123.0
# 76         13.0      95.9  112.1    95.9       108.5    137.0
# 82         14.0     105.7  121.9   105.7       121.6    151.0
# 88         15.0     115.5  131.7   115.5       131.4    165.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 3             1.0              4.0             8.0          1.0    0.7
# 9             1.0              4.0             8.0          1.0    0.7
# 15            1.0              4.0             8.0          1.0    0.7
# 21            1.0              4.0             8.0          1.0    0.7
# 27            1.0              4.0             8.0          1.0    0.7
# 33            1.0              4.0             8.0          1.0    0.7
# 39            1.0              4.0             8.0          1.0    0.7
# 45            1.0              4.0             8.0          1.0    0.7
# 51            1.0              4.0             8.0          1.0    0.7
# 57            1.0              4.0             8.0          1.0    0.7
# 63            1.0              4.0             8.0          1.0    0.7
# 69            1.0              4.0             8.0          1.0    0.7
# 75            1.0              4.0             8.0          1.0    0.7
# 81            1.0              4.0             8.0          1.0    0.7
# 87            1.0              4.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 3           1.0       5.6    5.6     5.6         5.6      8.0
# 9           2.0      11.2   11.2    11.2        11.2     16.0
# 15          3.0      16.8   16.8    16.8        16.8     24.0
# 21          4.0      22.4   22.4    22.4        22.4     32.0
# 27          5.0      28.0   28.0    28.0        28.0     40.0
# 33          6.0      35.7   35.7    35.7        35.7     51.0
# 39          7.0      43.4   43.4    43.4        46.7     62.0
# 45          8.0      51.1   51.1    51.1        54.4     73.0
# 51          9.0      58.8   58.8    58.8        62.1     84.0
# 57         10.0      66.5   66.5    66.5        69.8     95.0
# 63         11.0      76.3   85.3    76.3        82.0    109.0
# 69         12.0      86.1   99.0    86.1        94.2    123.0
# 75         13.0      95.9  108.8    95.9       106.4    137.0
# 81         14.0     105.7  118.6   105.7       119.8    151.0
# 87         15.0     115.5  128.4   115.5       129.6    165.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 2             2.0              3.0             8.0          1.0    0.7
# 8             2.0              3.0             8.0          1.0    0.7
# 14            2.0              3.0             8.0          1.0    0.7
# 20            2.0              3.0             8.0          1.0    0.7
# 26            2.0              3.0             8.0          1.0    0.7
# 32            2.0              3.0             8.0          1.0    0.7
# 38            2.0              3.0             8.0          1.0    0.7
# 44            2.0              3.0             8.0          1.0    0.7
# 50            2.0              3.0             8.0          1.0    0.7
# 56            2.0              3.0             8.0          1.0    0.7
# 62            2.0              3.0             8.0          1.0    0.7
# 68            2.0              3.0             8.0          1.0    0.7
# 74            2.0              3.0             8.0          1.0    0.7
# 80            2.0              3.0             8.0          1.0    0.7
# 86            2.0              3.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 2           1.0       5.6    5.6     5.6         5.6      8.0
# 8           2.0      11.2   11.2    11.2        11.2     16.0
# 14          3.0      16.8   16.8    16.8        16.8     24.0
# 20          4.0      22.4   22.4    22.4        22.4     32.0
# 26          5.0      28.0   28.0    28.0        28.0     40.0
# 32          6.0      35.7   35.7    35.7        35.7     51.0
# 38          7.0      43.4   43.4    43.4        46.7     62.0
# 44          8.0      51.1   51.1    51.1        54.7     73.0
# 50          9.0      58.8   58.8    58.8        62.4     84.0
# 56         10.0      66.5   66.5    66.5        70.1     95.0
# 62         11.0      76.3   82.3    76.3        79.9    109.0
# 68         12.0      86.1   95.7    86.1        92.1    123.0
# 74         13.0      95.9  105.5    95.9       104.3    137.0
# 80         14.0     105.7  115.3   105.7       118.0    151.0
# 86         15.0     115.5  125.1   115.5       127.8    165.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 1             3.0              2.0             8.0          1.0    0.7
# 7             3.0              2.0             8.0          1.0    0.7
# 13            3.0              2.0             8.0          1.0    0.7
# 19            3.0              2.0             8.0          1.0    0.7
# 25            3.0              2.0             8.0          1.0    0.7
# 31            3.0              2.0             8.0          1.0    0.7
# 37            3.0              2.0             8.0          1.0    0.7
# 43            3.0              2.0             8.0          1.0    0.7
# 49            3.0              2.0             8.0          1.0    0.7
# 55            3.0              2.0             8.0          1.0    0.7
# 61            3.0              2.0             8.0          1.0    0.7
# 67            3.0              2.0             8.0          1.0    0.7
# 73            3.0              2.0             8.0          1.0    0.7
# 79            3.0              2.0             8.0          1.0    0.7
# 85            3.0              2.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 1           1.0       5.6    5.6     5.6         5.6      8.0
# 7           2.0      11.2   11.2    11.2        11.2     16.0
# 13          3.0      16.8   16.8    16.8        16.8     24.0
# 19          4.0      22.4   22.4    22.4        22.4     32.0
# 25          5.0      28.0   28.0    28.0        28.0     40.0
# 31          6.0      35.7   35.7    35.7        35.7     51.0
# 37          7.0      43.4   43.4    43.4        46.7     62.0
# 43          8.0      51.1   51.1    51.1        54.7     73.0
# 49          9.0      58.8   58.8    58.8        62.7     84.0
# 55         10.0      66.5   66.5    66.5        70.4     95.0
# 61         11.0      76.3   79.3    76.3        80.2    109.0
# 67         12.0      86.1   92.4    86.1        90.0    123.0
# 73         13.0      95.9  102.2    95.9       102.2    137.0
# 79         14.0     105.7  112.0   105.7       116.2    151.0
# 85         15.0     115.5  121.8   115.5       126.0    165.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 0             4.0              1.0             8.0          1.0    0.7
# 6             4.0              1.0             8.0          1.0    0.7
# 12            4.0              1.0             8.0          1.0    0.7
# 18            4.0              1.0             8.0          1.0    0.7
# 24            4.0              1.0             8.0          1.0    0.7
# 30            4.0              1.0             8.0          1.0    0.7
# 36            4.0              1.0             8.0          1.0    0.7
# 42            4.0              1.0             8.0          1.0    0.7
# 48            4.0              1.0             8.0          1.0    0.7
# 54            4.0              1.0             8.0          1.0    0.7
# 60            4.0              1.0             8.0          1.0    0.7
# 66            4.0              1.0             8.0          1.0    0.7
# 72            4.0              1.0             8.0          1.0    0.7
# 78            4.0              1.0             8.0          1.0    0.7
# 84            4.0              1.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 0           1.0       5.6    5.6     5.6         5.6      8.0
# 6           2.0      11.2   11.2    11.2        11.2     16.0
# 12          3.0      16.8   16.8    16.8        16.8     24.0
# 18          4.0      22.4   22.4    22.4        22.4     32.0
# 24          5.0      28.0   28.0    28.0        28.0     40.0
# 30          6.0      35.7   35.7    35.7        35.7     51.0
# 36          7.0      43.4   43.4    43.4        46.7     62.0
# 42          8.0      51.1   51.1    51.1        54.7     73.0
# 48          9.0      58.8   58.8    58.8        62.7     84.0
# 54         10.0      66.5   66.5    66.5        70.7     95.0
# 60         11.0      76.3   76.3    76.3        80.5    109.0
# 66         12.0      86.1   89.1    86.1        90.3    123.0
# 72         13.0      95.9   98.9    95.9       100.1    137.0
# 78         14.0     105.7  108.7   105.7       114.1    151.0
# 84         15.0     115.5  118.5   115.5       124.2    165.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  processingTime  arrivalRate  alpha  \
# 5             5.0              0.0             8.0          1.0    0.7
# 11            5.0              0.0             8.0          1.0    0.7
# 17            5.0              0.0             8.0          1.0    0.7
# 23            5.0              0.0             8.0          1.0    0.7
# 29            5.0              0.0             8.0          1.0    0.7
# 35            5.0              0.0             8.0          1.0    0.7
# 41            5.0              0.0             8.0          1.0    0.7
# 47            5.0              0.0             8.0          1.0    0.7
# 53            5.0              0.0             8.0          1.0    0.7
# 59            5.0              0.0             8.0          1.0    0.7
# 65            5.0              0.0             8.0          1.0    0.7
# 71            5.0              0.0             8.0          1.0    0.7
# 77            5.0              0.0             8.0          1.0    0.7
# 83            5.0              0.0             8.0          1.0    0.7
#
#     numCustomer  allQueue   SPNE  greedy  pessGreedy  allLine
# 5           2.0      11.2   11.2    11.2        11.2     16.0
# 11          3.0      16.8   16.8    16.8        16.8     24.0
# 17          4.0      22.4   22.4    22.4        22.4     32.0
# 23          5.0      28.0   28.0    28.0        28.0     40.0
# 29          6.0      35.7   35.7    35.7        35.7     51.0
# 35          7.0      43.4   43.4    43.4        43.4     62.0
# 41          8.0      51.1   51.1    51.1        51.1     73.0
# 47          9.0      58.8   58.8    58.8        58.8     84.0
# 53         10.0      66.5   66.5    66.5        66.5     95.0
# 59         11.0      76.3   76.3    76.3        76.3    109.0
# 65         12.0      86.1   86.1    86.1        86.1    123.0
# 71         13.0      95.9   95.9    95.9        95.9    137.0
# 77         14.0     105.7  105.7   105.7       105.7    151.0
# 83         15.0     115.5  115.5   115.5       115.5    165.0
# onlineBarista      float64
# physicalBarista    float64
# processingTime     float64
# arrivalRate        float64
# alpha              float64
# numCustomer        float64
# allQueue           float64
# SPNE               float64
# greedy             float64
# pessGreedy         float64
# allLine            float64
# dtype: object
